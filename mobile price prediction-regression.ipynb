# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\DELL\Downloads\archive (3)\SmartphonePrice.csv")

# %%
df
# Out:
#        Performance  Storage capacity  Camera quality  Battery life  \
# 0        23.300601                32       12.431075   1622.031664
# 1        12.211531                32       14.659343   1355.013292
# 2        35.734309                64       18.057053   1890.085187
# 3         6.228099                32       14.604991   1983.221565
# 4        22.575586                32       11.765278   1704.403240
# ...            ...               ...             ...           ...
# 10995    34.643328                64       30.307368   1983.912048
# 10996    99.270542              1024       51.763207   5943.655889
# 10997    31.156171                64       24.153839   1975.952952
# 10998    20.045263                16       11.055361   1240.291660
# 10999    86.599801              1024       90.384734   5674.506043
#
#            Weight       age        Price
# 0      200.517214  4.775774    74.269613
# 1      158.487617  7.177409    -5.464359
# ...

# %% [markdown]
# <h1>Inspection</h1>

# %%
# first 5 rows of data
df.head()
# Out:
#    Performance  Storage capacity  Camera quality  Battery life      Weight  \
# 0    23.300601                32       12.431075   1622.031664  200.517214
# 1    12.211531                32       14.659343   1355.013292  158.487617
# 2    35.734309                64       18.057053   1890.085187  146.396101
# 3     6.228099                32       14.604991   1983.221565  211.711960
# 4    22.575586                32       11.765278   1704.403240  245.333160
#
#         age      Price
# 0  4.775774  74.269613
# 1  7.177409  -5.464359
# 2  5.519491  66.803027
# 3  9.218902 -59.435109
# 4  8.218348  -4.319112

# %%
# first 20 rows
df.head(20)
# Out:
#     Performance  Storage capacity  Camera quality  Battery life      Weight  \
# 0     23.300601                32       12.431075   1622.031664  200.517214
# 1     12.211531                32       14.659343   1355.013292  158.487617
# 2     35.734309                64       18.057053   1890.085187  146.396101
# 3      6.228099                32       14.604991   1983.221565  211.711960
# 4     22.575586                32       11.765278   1704.403240  245.333160
# 5     72.035567               256       48.545472   3804.895558  182.246561
# 6     89.966831               512       70.520066   3221.029718  170.223012
# 7     47.128484                32       30.113373   1800.263801  223.147262
# 8     70.861547               512       90.129013   3288.325136  163.911324
# 9      8.447973                32       14.527304   1504.641781  147.090836
# 10    72.556238               512       67.672210   3549.211315  217.021578
# ...

# %%
# last 5 rows
df.tail()
# Out:
#        Performance  Storage capacity  Camera quality  Battery life  \
# 10995    34.643328                64       30.307368   1983.912048
# 10996    99.270542              1024       51.763207   5943.655889
# 10997    31.156171                64       24.153839   1975.952952
# 10998    20.045263                16       11.055361   1240.291660
# 10999    86.599801              1024       90.384734   5674.506043
#
#            Weight       age        Price
# 10995  161.758819  3.255675   103.382921
# 10996  152.482320  1.676054  1039.880473
# 10997  135.867960  5.777607    50.422278
# 10998  127.392006  1.035853     3.382134
# 10999  169.549753  0.289742  1000.005244

# %%
# last 20 rows
df.tail(20)
# Out:
#        Performance  Storage capacity  Camera quality  Battery life  \
# 10980    88.987070              1024      129.903631   3307.339960
# 10981    34.744873                32       16.158964   1990.762429
# 10982    92.864165              1024      109.615355   4815.477545
# 10983    20.457220                16        8.794926   1022.717487
# 10984    68.054645                64       38.034578   2640.563510
# 10985    75.485937               512       84.008853   3460.724240
# 10986    83.476663               512       63.007187   3118.704522
# 10987    90.147104               512       53.605748   4120.378573
# 10988    93.987355               512      185.490648   5444.752054
# 10989    29.670352                16        9.986462   1049.327768
# 10990    29.860305                32       14.412397   1602.511759
# 10991    97.412010               512      157.348312   5152.756002
# 10992    24.087430                32       15.517028   1564.825969
# ...

# %%
# randomly selects 1 rows
df.sample()
# Out:
#       Performance  Storage capacity  Camera quality  Battery life     Weight  \
# 3507    68.630389                64       25.519039   2304.378305  190.66323
#
#            age       Price
# 3507  5.580606  279.892637

# %%
# gives statistical summary of df
df.describe()
# Out:
#         Performance  Storage capacity  Camera quality  Battery life  \
# count  11000.000000      11000.000000    11000.000000  11000.000000
# mean      50.435169        203.131636       45.802826   2547.068570
# std       28.867668        245.622209       45.511607   1140.140746
# min        0.010832         16.000000        8.000402   1000.321170
# 25%       25.363476         32.000000       14.180256   1806.277707
# 50%       50.581148         64.000000       26.387082   2019.869317
# 75%       75.527634        256.000000       63.205526   3296.367340
# max       99.981171       1024.000000      207.756627   5999.391019
#
#              Weight           age         Price
# count  11000.000000  11000.000000  11000.000000
# mean     185.456464      3.307602    311.659876
# std       37.789340      2.625388    302.076743
# min      120.013940      0.000628   -126.091022
# 25%      152.573402      1.152325     57.359957
# 50%      185.709779      2.448089    232.693845
# ...

# %%
# information about df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11000 entries, 0 to 10999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Performance       11000 non-null  float64
#  1   Storage capacity  11000 non-null  int64
#  2   Camera quality    11000 non-null  float64
#  3   Battery life      11000 non-null  float64
#  4   Weight            11000 non-null  float64
#  5   age               11000 non-null  float64
#  6   Price             11000 non-null  float64
# dtypes: float64(6), int64(1)
# memory usage: 601.7 KB

# %%
# returns columns
df.columns
# Out:
# Index(['Performance', 'Storage capacity', 'Camera quality', 'Battery life',
#        'Weight', 'age', 'Price'],
#       dtype='object')

# %%
# datatypes of all columns
df.dtypes
# Out:
# Performance         float64
# Storage capacity      int64
# Camera quality      float64
# Battery life        float64
# Weight              float64
# age                 float64
# Price               float64
# dtype: object

# %%
# shape of df
df.shape
# Out:
# (11000, 7)

# %%
# reteriving single col
df['Storage capacity']
# Out:
# 0          32
# 1          32
# 2          64
# 3          32
# 4          32
#          ...
# 10995      64
# 10996    1024
# 10997      64
# 10998      16
# 10999    1024
# Name: Storage capacity, Length: 11000, dtype: int64

# %%
df['Price']
# Out:
# 0          74.269613
# 1          -5.464359
# 2          66.803027
# 3         -59.435109
# 4          -4.319112
#             ...
# 10995     103.382921
# 10996    1039.880473
# 10997      50.422278
# 10998       3.382134
# 10999    1000.005244
# Name: Price, Length: 11000, dtype: float64

# %%
df['Performance']
# Out:
# 0        23.300601
# 1        12.211531
# 2        35.734309
# 3         6.228099
# 4        22.575586
#            ...
# 10995    34.643328
# 10996    99.270542
# 10997    31.156171
# 10998    20.045263
# 10999    86.599801
# Name: Performance, Length: 11000, dtype: float64

# %%
# multiple column from df
df[['Camera quality','Battery life']]
# Out:
#        Camera quality  Battery life
# 0           12.431075   1622.031664
# 1           14.659343   1355.013292
# 2           18.057053   1890.085187
# 3           14.604991   1983.221565
# 4           11.765278   1704.403240
# ...               ...           ...
# 10995       30.307368   1983.912048
# 10996       51.763207   5943.655889
# 10997       24.153839   1975.952952
# 10998       11.055361   1240.291660
# 10999       90.384734   5674.506043
#
# [11000 rows x 2 columns]

# %%
df[['Weight','age']]
# Out:
#            Weight       age
# 0      200.517214  4.775774
# 1      158.487617  7.177409
# 2      146.396101  5.519491
# 3      211.711960  9.218902
# 4      245.333160  8.218348
# ...           ...       ...
# 10995  161.758819  3.255675
# 10996  152.482320  1.676054
# 10997  135.867960  5.777607
# 10998  127.392006  1.035853
# 10999  169.549753  0.289742
#
# [11000 rows x 2 columns]

# %%
# unique values
df['age'].unique()
# Out:
# array([4.77577373, 7.1774086 , 5.5194909 , ..., 5.77760653, 1.03585252,
#        0.28974194])

# %%
# unique values
df['Battery life'].unique()
# Out:
# array([1622.03166365, 1355.01329239, 1890.0851866 , ..., 1975.95295192,
#        1240.29165966, 5674.50604275])

# %%
df['Storage capacity'].unique()
# Out:
# array([  32,   64,  256,  512,   16, 1024,  128], dtype=int64)

# %%
# taking unique values of all col
col=df.columns
for i in col:
    print("column:",i)
    print("unique values")
    print(df[i].unique())
    print("------------------")
# Out:
# column: Performance
# unique values
# [23.30060052 12.21153142 35.73430935 ... 31.1561715  20.04526345
#  86.59980057]
# ------------------
# column: Storage capacity
# unique values
# [  32   64  256  512   16 1024  128]
# ------------------
# column: Camera quality
# unique values
# [12.43107518 14.65934274 18.05705308 ... 24.15383942 11.05536103
#  90.38473396]
# ------------------
# column: Battery life
# unique values
# [1622.03166365 1355.01329239 1890.0851866  ... 1975.95295192 1240.29165966
#  5674.50604275]
# ------------------
# column: Weight
# unique values
# [200.51721397 158.48761745 146.39610114 ... 135.86795979 127.39200605
#  169.54975323]
# ------------------
# column: age
# unique values
# [4.77577373 7.1774086  5.5194909  ... 5.77760653 1.03585252 0.28974194]
# ------------------
# column: Price
# unique values
# [  74.26961321   -5.4643591    66.80302685 ...   50.42227844    3.38213361
#  1000.00524411]
# ------------------

# %%
# value_counts
df['Price'].value_counts()
# Out:
# 74.269613      1
# 548.280489     1
# 40.142758      1
# 312.111409     1
# 698.795559     1
#               ..
# 65.643993      1
# 85.209952      1
# 1003.363286    1
# 411.273424     1
# 1000.005244    1
# Name: Price, Length: 11000, dtype: int64

# %%
# displays all value_counts
col=df.columns
for i in col:
    print("column:",i)
    print("value counts foe column",i)
    print(df[i].value_counts())
    print("------------------")
# Out:
# column: Performance
# value counts foe column Performance
# 23.300601    1
# 75.008496    1
# 23.131152    1
# 61.034686    1
# 98.526007    1
#             ..
# 38.588138    1
# 38.207793    1
# 91.676044    1
# 64.809591    1
# 86.599801    1
# Name: Performance, Length: 11000, dtype: int64
# ------------------
# column: Storage capacity
# value counts foe column Storage capacity
# 32      2692
# 512     2124
# 64      1796
# 16      1669
# 256     1550
# 128      753
# 1024     416
# Name: Storage capacity, dtype: int64
# ------------------
# column: Camera quality
# value counts foe column Camera quality
# 12.431075     1
# 98.384787     1
# 15.102162     1
# 44.219079     1
# 70.101859     1
#              ..
# 21.974426     1
# 13.597216     1
# 197.812124    1
# 46.610475     1
# 90.384734     1
# Name: Camera quality, Length: 11000, dtype: int64
# ------------------
# column: Battery life
# value counts foe column Battery life
# 1622.031664    1
# 3979.890672    1
# ...

# %%
df
# Out:
#        Performance  Storage capacity  Camera quality  Battery life  \
# 0        23.300601                32       12.431075   1622.031664
# 1        12.211531                32       14.659343   1355.013292
# 2        35.734309                64       18.057053   1890.085187
# 3         6.228099                32       14.604991   1983.221565
# 4        22.575586                32       11.765278   1704.403240
# ...            ...               ...             ...           ...
# 10995    34.643328                64       30.307368   1983.912048
# 10996    99.270542              1024       51.763207   5943.655889
# 10997    31.156171                64       24.153839   1975.952952
# 10998    20.045263                16       11.055361   1240.291660
# 10999    86.599801              1024       90.384734   5674.506043
#
#            Weight       age        Price
# 0      200.517214  4.775774    74.269613
# 1      158.487617  7.177409    -5.464359
# ...

# %%
# Storage capacity more than 32
df[df['Storage capacity']>32]
# Out:
#        Performance  Storage capacity  Camera quality  Battery life  \
# 2        35.734309                64       18.057053   1890.085187
# 5        72.035567               256       48.545472   3804.895558
# 6        89.966831               512       70.520066   3221.029718
# 8        70.861547               512       90.129013   3288.325136
# 10       72.556238               512       67.672210   3549.211315
# ...            ...               ...             ...           ...
# 10991    97.412010               512      157.348312   5152.756002
# 10995    34.643328                64       30.307368   1983.912048
# 10996    99.270542              1024       51.763207   5943.655889
# 10997    31.156171                64       24.153839   1975.952952
# 10999    86.599801              1024       90.384734   5674.506043
#
#            Weight       age        Price
# 2      146.396101  5.519491    66.803027
# 5      182.246561  1.958366   461.950703
# ...

# %%
# Retrieve rows where the phone is lightweight
df[df['Weight']<150]
# Out:
#        Performance  Storage capacity  Camera quality  Battery life  \
# 2        35.734309                64       18.057053   1890.085187
# 9         8.447973                32       14.527304   1504.641781
# 11       92.982423               512       67.018116   5595.223343
# 20       94.402889              1024       52.374430   5078.628527
# 22       34.392090                32       25.579929   1911.715995
# ...            ...               ...             ...           ...
# 10988    93.987355               512      185.490648   5444.752054
# 10992    24.087430                32       15.517028   1564.825969
# 10993    16.271015                16       13.843556   1444.405661
# 10997    31.156171                64       24.153839   1975.952952
# 10998    20.045263                16       11.055361   1240.291660
#
#            Weight       age       Price
# 2      146.396101  5.519491   66.803027
# 9      147.090836  8.604896  -41.282624
# ...

# %%
# Retrieve rows where the phone is high-end
df[df['Performance']>30]
# Out:
#        Performance  Storage capacity  Camera quality  Battery life  \
# 2        35.734309                64       18.057053   1890.085187
# 5        72.035567               256       48.545472   3804.895558
# 6        89.966831               512       70.520066   3221.029718
# 7        47.128484                32       30.113373   1800.263801
# 8        70.861547               512       90.129013   3288.325136
# ...            ...               ...             ...           ...
# 10991    97.412010               512      157.348312   5152.756002
# 10995    34.643328                64       30.307368   1983.912048
# 10996    99.270542              1024       51.763207   5943.655889
# 10997    31.156171                64       24.153839   1975.952952
# 10999    86.599801              1024       90.384734   5674.506043
#
#            Weight       age        Price
# 2      146.396101  5.519491    66.803027
# 5      182.246561  1.958366   461.950703
# ...

# %%
# Retrieve expensive phones with a high-quality camera
df[df['Price']>1000][['Price', 'Camera quality']]
# Out:
#              Price  Camera quality
# 30     1099.162671      151.246252
# 45     1044.277185      190.458630
# 123    1052.444802      185.094011
# 141    1018.741438       65.198394
# 161    1049.709018       83.393228
# ...            ...             ...
# 10887  1019.121865      179.478110
# 10973  1057.003364      194.964526
# 10982  1034.991430      109.615355
# 10996  1039.880473       51.763207
# 10999  1000.005244       90.384734
#
# [164 rows x 2 columns]

# %% [markdown]
# <h1>Filtering conditions</h1>

# %%
# Retrieve rows where the phone is overpriced
df[(df['Performance']>30)&(df['Price']<60000000)]
# Out:
#        Performance  Storage capacity  Camera quality  Battery life  \
# 2        35.734309                64       18.057053   1890.085187
# 5        72.035567               256       48.545472   3804.895558
# 6        89.966831               512       70.520066   3221.029718
# 7        47.128484                32       30.113373   1800.263801
# 8        70.861547               512       90.129013   3288.325136
# ...            ...               ...             ...           ...
# 10991    97.412010               512      157.348312   5152.756002
# 10995    34.643328                64       30.307368   1983.912048
# 10996    99.270542              1024       51.763207   5943.655889
# 10997    31.156171                64       24.153839   1975.952952
# 10999    86.599801              1024       90.384734   5674.506043
#
#            Weight       age        Price
# 2      146.396101  5.519491    66.803027
# 5      182.246561  1.958366   461.950703
# ...

# %%
# Retrieve phones that are lightweight and have good battery life
df[(df['Weight']<150) &(df['Battery life']>3000)]
# Out:
#        Performance  Storage capacity  Camera quality  Battery life  \
# 11       92.982423               512       67.018116   5595.223343
# 20       94.402889              1024       52.374430   5078.628527
# 38       71.157363               256      100.772769   3882.863196
# 43       70.795768               512       51.215882   3901.855385
# 88       80.984977               512       75.063910   3860.663124
# ...            ...               ...             ...           ...
# 10955    98.247186               512      132.924295   3247.881952
# 10959    70.502965               512      102.514574   3591.091857
# 10961    98.555986               512      151.946940   3949.632460
# 10973    86.559009              1024      194.964526   5482.090040
# 10988    93.987355               512      185.490648   5444.752054
#
#            Weight       age        Price
# 11     137.039415  0.543719   754.235150
# 20     122.521203  1.039056   929.340203
# ...

# %%
# Retrieve expensive phones or phones with a high-quality camera
df[(df['Price']>1000)|(df['Camera quality']>40)]
# Out:
#        Performance  Storage capacity  Camera quality  Battery life  \
# 5        72.035567               256       48.545472   3804.895558
# 6        89.966831               512       70.520066   3221.029718
# 8        70.861547               512       90.129013   3288.325136
# 10       72.556238               512       67.672210   3549.211315
# 11       92.982423               512       67.018116   5595.223343
# ...            ...               ...             ...           ...
# 10987    90.147104               512       53.605748   4120.378573
# 10988    93.987355               512      185.490648   5444.752054
# 10991    97.412010               512      157.348312   5152.756002
# 10996    99.270542              1024       51.763207   5943.655889
# 10999    86.599801              1024       90.384734   5674.506043
#
#            Weight       age        Price
# 5      182.246561  1.958366   461.950703
# 6      170.223012  0.273169   744.270945
# ...

# %%
# Retrieve phones that are lightweight or have long battery life
df[(df['Weight']<150)|(df['Battery life']>3000)]
# Out:
#        Performance  Storage capacity  Camera quality  Battery life  \
# 2        35.734309                64       18.057053   1890.085187
# 5        72.035567               256       48.545472   3804.895558
# 6        89.966831               512       70.520066   3221.029718
# 8        70.861547               512       90.129013   3288.325136
# 9         8.447973                32       14.527304   1504.641781
# ...            ...               ...             ...           ...
# 10993    16.271015                16       13.843556   1444.405661
# 10996    99.270542              1024       51.763207   5943.655889
# 10997    31.156171                64       24.153839   1975.952952
# 10998    20.045263                16       11.055361   1240.291660
# 10999    86.599801              1024       90.384734   5674.506043
#
#            Weight       age        Price
# 2      146.396101  5.519491    66.803027
# 5      182.246561  1.958366   461.950703
# ...

# %% [markdown]
# <h1>preprocessing</h1>

# %%
# checking null values
df.isna().sum()
# Out:
# Performance         0
# Storage capacity    0
# Camera quality      0
# Battery life        0
# Weight              0
# age                 0
# Price               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11000 entries, 0 to 10999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Performance       11000 non-null  float64
#  1   Storage capacity  11000 non-null  int64
#  2   Camera quality    11000 non-null  float64
#  3   Battery life      11000 non-null  float64
#  4   Weight            11000 non-null  float64
#  5   age               11000 non-null  float64
#  6   Price             11000 non-null  float64
# dtypes: float64(6), int64(1)
# memory usage: 601.7 KB

# %% [markdown]
# <h1>Visualization</h1>

# %%
import matplotlib.pyplot as plt

phone_df = df[(df['Performance']>70)&(df['Price']<1000000)][['Performance','Price']]
x, y = phone_df['Performance'], phone_df['Price']
plt.figure(figsize=(8,6), dpi=100)
plt.scatter(x, y, color='blue')
plt.title("Performance vs Price")
plt.xlabel("Performance Score")
plt.ylabel("Price in USD")
plt.show()

# %%
# bar graph

import matplotlib.pyplot as plt

# Count phones per performance category
life_counts = df['Battery life'].value_counts()

# Extract x (price) and y (counts)
x=life_counts.index
y=life_counts.values

# Plot bar chart
plt.figure(figsize=(8,6), dpi=100)
plt.bar(x, y,color="orange")
plt.title("Life of a Battery")
plt.xlabel("Battery life")
plt.ylabel("Number of Phones")
plt.show()

# %%
import matplotlib.pyplot as plt

# Create histogram for phone price distribution
plt.figure(figsize=(8,6), dpi=100)
plt.hist(df['Price'], bins=10, color='red')
plt.title("Distribution of Smartphone Prices")
plt.xlabel("Price (USD)")
plt.ylabel("Frequency")
plt.show()

# %%
# Aggregate smartphone count by storage capacity
storage_distribution = df.groupby('Storage capacity').size()

# Create pie chart for smartphone distribution by storage capacity
plt.figure(figsize=(8,6), dpi=100)
plt.pie(storage_distribution, labels=storage_distribution.index, 
        colors=['blue', 'green', 'red', 'purple', 'orange', 'cyan'])
plt.title("Smartphone Distribution by Storage Capacity")
plt.legend(storage_distribution.index, loc="upper left")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11000 entries, 0 to 10999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Performance       11000 non-null  float64
#  1   Storage capacity  11000 non-null  int64
#  2   Camera quality    11000 non-null  float64
#  3   Battery life      11000 non-null  float64
#  4   Weight            11000 non-null  float64
#  5   age               11000 non-null  float64
#  6   Price             11000 non-null  float64
# dtypes: float64(6), int64(1)
# memory usage: 601.7 KB

# %% [markdown]
# <h1>labeling the data</h1>
# <style>color:"pink"</style>

# %%
x=df.drop('Price',axis=1)
y=df['Price']

# %%
x.shape
# Out:
# (11000, 6)

# %%
y.shape
# Out:
# (11000,)

# %% [markdown]
# <h1>spliting the data</h1>
# <style>color:"red" </style>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape
# Out:
# (8800, 6)

# %%
y_train.shape
# Out:
# (8800,)

# %%
x_test.shape
# Out:
# (2200, 6)

# %%
y_test.shape
# Out:
# (2200,)

# %% [markdown]
# <h1>Feature Engineering</h1>
# <style>color:"pink"</style>

# %%
#import
#from sklearn.preprocessing import MiniMaxScaler
from sklearn.preprocessing import StandardScaler
#class

# %%
features_to_scale = ['Storage capacity', 'Camera quality', 'Battery life', 'Weight']

# %%
#create object to the class
scaler = StandardScaler()
df[features_to_scale] = scaler.fit_transform(df[features_to_scale])

# %%
#scaling the input values
x_train=scaler.fit_transform(x_train)
x_train
# Out:
# array([[ 1.08493742,  1.25870037,  0.18533082,  1.21371421,  0.64447002,
#         -0.9113031 ],
#        [-0.23059538, -0.6951138 , -0.5236447 , -0.54995512, -1.22444078,
#          0.97630069],
#        [ 0.0171544 , -0.30435096, -0.37874864,  0.35833316,  0.70950111,
#          0.78922082],
#        ...,
#        [-0.29722429, -0.56485952, -0.62059857, -0.53319165, -0.5874741 ,
#          0.96926365],
#        [-1.35503515, -0.6951138 , -0.75572907, -0.95603665, -1.00134924,
#         -0.44761092],
#        [ 0.17260701, -0.56485952, -0.16575613, -0.46020921,  0.52443969,
#         -0.61600913]])

# %%
x_test=scaler.transform(x_test)
x_test
# Out:
# array([[-1.61426996, -0.6951138 , -0.80281501, -0.54448082,  0.53042334,
#         -0.30680514],
#        [ 1.06486187,  1.25870037,  0.33801851,  0.71271902, -1.65078275,
#         -1.11808721],
#        [ 0.99000328,  1.25870037,  0.87034858,  0.4489    , -0.13499288,
#         -0.87065997],
#        ...,
#        [ 0.5750901 , -0.56485952, -0.61098485,  0.19770103, -0.64908809,
#         -0.06130197],
#        [ 0.31707237, -0.30435096, -0.63522158, -0.00444198,  0.80311348,
#         -1.14495188],
#        [-0.06241886, -0.6951138 , -0.61013996, -0.60374476,  1.39614388,
#         -0.62094854]])

# %% [markdown]
# <h1>MODEL BUILDING, TRAINING, TESTING AND EVALUATION</h1>
# <style color:"red" </style>

# %%
# model building
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
# model training 
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# model testing
result=lr.predict(x_test)
result
# Out:
# array([ 43.04088015, 664.78083119, 640.10118743, ..., 294.75091411,
#        334.15471531, 197.70394011])

# %%
# decision tree regressor

from sklearn.tree import DecisionTreeRegressor
dt=DecisionTreeRegressor()


# model training
dt.fit(x_train, y_train)

# model testing
dt_result=dt.predict(x_test)
dt_result


# model evalutaion for regression
from sklearn.metrics import mean_absolute_error,mean_squared_error,root_mean_squared_error
import numpy as np
mae=mean_absolute_error(y_test,dt_result)
mse=mean_squared_error(y_test,dt_result)
rmse = np.sqrt(mse)
# rmse=root_mean_squared_error(y_test,result)
print("MAE",mae)
print("MSE",mse)
print("RMSE",rmse)
# Out:
# MAE 25.45129658246632
# MSE 1542.7387631587033
# RMSE 39.27771331376998

# %%
# random forest regressor

from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()

# model training
rf.fit(x_train, y_train)

# model testing
rf_result=rf.predict(x_test)
rf_result

# model evalutaion for regression
from sklearn.metrics import mean_absolute_error,mean_squared_error,root_mean_squared_error
import numpy as np
mae=mean_absolute_error(y_test,rf_result)
mse=mean_squared_error(y_test,rf_result)
rmse = np.sqrt(mse)
# rmse=root_mean_squared_error(y_test,result)
print("MAE",mae)
print("MSE",mse)
print("RMSE",rmse)
# Out:
# MAE 19.182235389608422
# MSE 822.3429198359711
# RMSE 28.676522101467796

# %%
# model score
train_score=lr.score(x_train,y_train)
test_score=lr.score(x_test,y_test)
print("LR MODEL TRAIN SCORE",train_score)
print("LR MODEL TEST SCORE",test_score)
# Out:
# LR MODEL TRAIN SCORE 0.9814347175456363
# LR MODEL TEST SCORE 0.9809878830241924

# %% [markdown]
# <h1>DEPLOYMENT</h1>
# <style "color:red;"  </style>

# %%
import pickle

# %%
with open("place-scaler-model.pkl","wb")as file:
    pickle.dump(scaler,file)

# %%
with open("mobile-rf-model.pkl","wb")as file:
    pickle.dump(rf,file)

# %%
# step 2:loading the saved model
with open("place-scaler-model.pkl","rb")as file:
    place_model=pickle.load(file)

# %%
# step 2:loading the saved model
with open("mobile-rf-model.pkl","rb")as file:
    price_model=pickle.load(file)

# %%
def predict_phone_quality(performance=8.5, storage_capacity=128, camera_quality=9.0, battery_life=24, weight=180, age=1.0):
    # Prepare feature list in the correct order
    features = [
        float(performance),
        int(storage_capacity),
        float(camera_quality),
        float(battery_life),
        float(weight),
        float(age)
    ]

    # Ensure the correct number of features
    if len(features) != 6:
        print("Error: Feature list does not have 6 elements.")
        print("Current features:", features)
        return

    # Convert to 2D array for scaler
    features_array = np.array([features])

    # Apply standard scaling
    features_scaled = scaler.transform(features_array)

    # Predict using the scaled input
    result = rf.predict(features_scaled)
    print("Raw model output:", result)
    return result[0]

# %%
predict_phone_quality()
# Out:
# Raw model output: [85.09939989]
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 85.09939989138286

# %%
performance= float(input("Enter performance: "))
storage_capacity = int(input("Enter storage_capacity: "))
camera_quality = float(input("Enter camera quality: "))
battery_life = int(input("Enter battery_life: "))
weight = int(input("Enter weight: "))
age = float(input("Enter age: "))


# Prediction
result = predict_phone_quality(performance, storage_capacity, camera_quality, battery_life,weight, age)
print("Model prediction result:", result)
# Out:
# Enter performance: 9
# Enter storage_capacity: 128
# Enter camera quality: 8.0
# Enter battery_life: 24
# Enter weight: 180
# Enter age: 1.0
# Raw model output: [86.15750956]
# Model prediction result: 86.15750955834696
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
# apply scaling
# even in deployment
# function return should be result ,no need of if condition for return
